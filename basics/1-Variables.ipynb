# %%
can = "Soda"
print(can)
can
# Out:
# Soda
# 'Soda'

# %%
type(can)
# Out:
# str

# %%
pizza=100
pizza
# Out:
# 100

# %%
type(pizza)
samosa = 100
ice_cream=250.2
total = pizza + samosa + ice_cream
print(total)
# Out:
# 450.2

# %%
print(type(total));
type(total)
# Out:
# <class 'float'>
# float

# %%
total > 200
# Out:
# True

# %%
total < 200
# Out:
# False

# %%
above_threshold = total > 200
above_threshold
# Out:
# True

# %%
type(above_threshold)
# Out:
# bool

# %%
type(can)
# Out:
# str

# %%
can =6.7
type(can)
# Out:
# float

# %%
foo = "jilebi"
id(foo)
# Out:
# 2776303407184

# %%
bar = foo
foo
# Out:
# 'jilebi'

# %%
id(bar)
# Out:
# 2776303407184

# %%
print(id(foo))
print(id(bar))
# Out:
# 2776303407184
# 2776303407184

# %%
#True = "banana"
# Caanot assign
#def =" test"

# %%
#@name = "dgs" 
#Cannot assign
